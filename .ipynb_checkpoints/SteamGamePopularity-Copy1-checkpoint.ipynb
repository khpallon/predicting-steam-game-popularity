# %% [markdown]
# # Import datasets

# %%
import pandas as pd

# %%
popularity = pd.read_csv("steamcharts.csv")
appdata = pd.read_csv("steam_app_data.csv", dtype={10: "string"})
headers = pd.read_csv("id_name.csv")

# %% [markdown]
# # Keep only rows that we have player data for

# %% [markdown]
# **Part of the cleaning process, does nothing the second time around**

# %%
usable_ids = popularity['steam_appid'].unique()

# %%
appdata = appdata[appdata['steam_appid'].isin(usable_ids)]
headers = headers[headers['appid'].isin(usable_ids)]

# %% [markdown]
# ## Write the changes back to file - save space

# %%
appdata.to_csv('steam_app_data.csv', index=False)
headers.to_csv('id_name.csv', index=False)

# %%
appdata.columns
# Out:
# Index(['type', 'name', 'steam_appid', 'required_age', 'is_free',
#        'controller_support', 'dlc', 'detailed_description', 'about_the_game',
#        'short_description', 'fullgame', 'supported_languages', 'header_image',
#        'website', 'pc_requirements', 'mac_requirements', 'linux_requirements',
#        'legal_notice', 'drm_notice', 'ext_user_account_notice', 'developers',
#        'publishers', 'demos', 'price_overview', 'packages', 'package_groups',
#        'platforms', 'metacritic', 'reviews', 'categories', 'genres',
#        'screenshots', 'movies', 'recommendations', 'achievements',
#        'release_date', 'support_info', 'background', 'content_descriptors'],
#       dtype='object')

# %%
popularity.columns
# Out:
# Index(['month', 'avg_players', 'gain', 'gain_percent', 'peak_players', 'name',
#        'steam_appid'],
#       dtype='object')

# %%
#Removing columns that will not be of use
appdata = appdata.drop(['name','dlc', 'detailed_description', 'about_the_game','short_description',
                        'fullgame','header_image','website', 'pc_requirements', 'mac_requirements','linux_requirements','legal_notice',
                        'drm_notice', 'ext_user_account_notice', 'demos', 'price_overview',
                        'packages', 'package_groups', 'reviews','screenshots','movies', 'achievements', 'controller_support', 'metacritic',
                        'support_info', 'background','content_descriptors', 'recommendations'], axis=1)
popularity = popularity.drop(['name', 'gain'],  axis=1)

# %%
appdata.columns
# Out:
# Index(['type', 'steam_appid', 'required_age', 'is_free', 'supported_languages',
#        'developers', 'publishers', 'platforms', 'categories', 'genres',
#        'release_date'],
#       dtype='object')

# %%
#Changing data types
popularity['month'] = pd.to_datetime(popularity['month'], format='%b-%y')
#In case it interprets 25 as 1925 and not 2025
popularity.loc[popularity['month'].dt.year < 2000, 'month'] += pd.DateOffset(years=100)

# %% [markdown]
# # Merging datasets

# %%
headers.head()
# Out:
#    appid                       name
# 0     10             Counter-Strike
# 1     20      Team Fortress Classic
# 2     30              Day of Defeat
# 3     40         Deathmatch Classic
# 4     50  Half-Life: Opposing Force

# %%
popularity.head()
# Out:
#        month  avg_players  gain_percent  peak_players  steam_appid
# 0 2025-09-01      7805.25        0.1276         13254           10
# 1 2025-08-01      6922.13       -0.0610         12168           10
# 2 2025-07-01      7371.48       -0.1016         13951           10
# 3 2025-06-01      8204.98       -0.0936         15798           10
# 4 2025-05-01      9052.51       -0.0495         15333           10

# %%
appdata.head()
# Out:
#    type  steam_appid  required_age is_free  \
# 0  game           10           0.0   False
# 1  game           20           0.0   False
# 2  game           30           0.0   False
# 3  game           40           0.0   False
# 4  game           50           0.0   False
#
#                                  supported_languages            developers  \
# 0  English<strong>*</strong>, French<strong>*</st...             ['Valve']
# 1  English, French, German, Italian, Spanish - Sp...             ['Valve']
# 2  English, French, German, Italian, Spanish - Spain             ['Valve']
# 3  English, French, German, Italian, Spanish - Sp...             ['Valve']
# 4                    English, French, German, Korean  ['Gearbox Software']
#
#   publishers                                      platforms  \
# 0  ['Valve']  {'windows': True, 'mac': True, 'linux': True}
# 1  ['Valve']  {'windows': True, 'mac': True, 'linux': True}
# 2  ['Valve']  {'windows': True, 'mac': True, 'linux': True}
# 3  ['Valve']  {'windows': True, 'mac': True, 'linux': True}
# 4  ['Valve']  {'windows': True, 'mac': True, 'linux': True}
#
#                                           categories  \
# 0  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 1  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 2  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 3  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 4  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                    genres  \
# 0  [{'id': '1', 'description': 'Action'}]
# 1  [{'id': '1', 'description': 'Action'}]
# 2  [{'id': '1', 'description': 'Action'}]
# 3  [{'id': '1', 'description': 'Action'}]
# 4  [{'id': '1', 'description': 'Action'}]
#
#                                     release_date
# 0  {'coming_soon': False, 'date': '1 Nov, 2000'}
# 1  {'coming_soon': False, 'date': '1 Apr, 1999'}
# 2  {'coming_soon': False, 'date': '1 May, 2003'}
# 3  {'coming_soon': False, 'date': '1 Jun, 2001'}
# 4  {'coming_soon': False, 'date': '1 Nov, 1999'}

# %%
main = (
    popularity
        .merge(headers, left_on='steam_appid', right_on='appid', how='left')
        .merge(appdata, on='steam_appid', how='left')
)

main = main.drop(columns='appid')
main.head()
# Out:
#        month  avg_players  gain_percent  peak_players  steam_appid  \
# 0 2025-09-01      7805.25        0.1276         13254           10
# 1 2025-08-01      6922.13       -0.0610         12168           10
# 2 2025-07-01      7371.48       -0.1016         13951           10
# 3 2025-06-01      8204.98       -0.0936         15798           10
# 4 2025-05-01      9052.51       -0.0495         15333           10
#
#              name  type  required_age is_free  \
# 0  Counter-Strike  game           0.0   False
# 1  Counter-Strike  game           0.0   False
# 2  Counter-Strike  game           0.0   False
# 3  Counter-Strike  game           0.0   False
# 4  Counter-Strike  game           0.0   False
#
#                                  supported_languages developers publishers  \
# 0  English<strong>*</strong>, French<strong>*</st...  ['Valve']  ['Valve']
# 1  English<strong>*</strong>, French<strong>*</st...  ['Valve']  ['Valve']
# 2  English<strong>*</strong>, French<strong>*</st...  ['Valve']  ['Valve']
# 3  English<strong>*</strong>, French<strong>*</st...  ['Valve']  ['Valve']
# 4  English<strong>*</strong>, French<strong>*</st...  ['Valve']  ['Valve']
#
#                                        platforms  \
# 0  {'windows': True, 'mac': True, 'linux': True}
# 1  {'windows': True, 'mac': True, 'linux': True}
# 2  {'windows': True, 'mac': True, 'linux': True}
# 3  {'windows': True, 'mac': True, 'linux': True}
# 4  {'windows': True, 'mac': True, 'linux': True}
#
#                                           categories  \
# 0  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 1  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 2  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 3  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 4  [{'id': 1, 'description': 'Multi-player'}, {'i...
#
#                                    genres  \
# 0  [{'id': '1', 'description': 'Action'}]
# 1  [{'id': '1', 'description': 'Action'}]
# 2  [{'id': '1', 'description': 'Action'}]
# 3  [{'id': '1', 'description': 'Action'}]
# 4  [{'id': '1', 'description': 'Action'}]
#
#                                     release_date
# 0  {'coming_soon': False, 'date': '1 Nov, 2000'}
# 1  {'coming_soon': False, 'date': '1 Nov, 2000'}
# 2  {'coming_soon': False, 'date': '1 Nov, 2000'}
# 3  {'coming_soon': False, 'date': '1 Nov, 2000'}
# 4  {'coming_soon': False, 'date': '1 Nov, 2000'}

# %%
import re

def clean_languages(cell):
    if pd.isna(cell):
        return []
    # Remove HTML tags
    text = re.sub(r'<.*?>', '', cell)
    # Remove extra notes like "*languages with full audio support"
    text = re.sub(r'\*.*languages with full audio support', '', text, flags=re.IGNORECASE)
    languages = [lang.strip() for lang in text.split(',') if lang.strip()]
    # Split by comma
    return languages

# Apply cleaning
main['supported_languages_clean'] = main['supported_languages'].apply(clean_languages)

# Flatten all lists to get unique languages
all_languages = [lang for sublist in main['supported_languages_clean'] for lang in sublist]
unique_languages = sorted(set(all_languages))

print(unique_languages)
# Out:
# ['#lang_slovakian', 'Afrikaans', 'Albanian', 'Alemán', 'Alemán*', 'Alemão', 'Alemão*', 'Allemand', 'Allemand*', 'Amharic', 'Angielski', 'Angielski*', 'Anglais', 'Anglais*', 'Anglais**Langues avec support audio complet', 'Angol*', 'Arabic', 'Arabisch', 'Armenian', 'Assamese', 'Azerbaijani', 'Bangla', 'Basque', 'Belarusian', 'Bhs. Belanda', 'Bhs. Ceko*bahasa dengan dukungan audio penuh', 'Bhs. Inggris*', 'Bhs. Italia*', 'Bhs. Jepang*', 'Bhs. Jerman*', 'Bhs. Korea', 'Bhs. Polandia', 'Bhs. Portugis - Brasil*', 'Bhs. Prancis*', 'Bhs. Rusia*', 'Bhs. Spanyol - Spanyol*', 'Bhs. Tionghoa Sederhana', 'Bhs. Tionghoa Tradisional', 'Bosnian', 'Brasilianisches Portugiesisch', 'Brasilianisches Portugiesisch*', 'Brasilianisches Portugiesisch*Sprachen mit voller Audiounterstützung', 'Brazíliai portugál', 'Bulgarian', 'Bułgarski', 'Búlgaro', 'Catalan', 'Ceco*lingue con supporto audio completo', 'Checo', 'Checo*idiomas con localización de audio', 'Cherokee', 'Chinesisch (traditionell)', 'Chinesisch (traditionell)*Sprachen mit voller Audiounterstützung', 'Chinesisch (vereinfacht)', 'Chinesisch (vereinfacht)*', 'Chinesisch (vereinfacht)*Sprachen mit voller Audiounterstützung', 'Chino simplificado', 'Chino simplificado*idiomas con localización de audio', 'Chino tradicional', 'Chino tradicional*idiomas con localización de audio', 'Chinois simplifié', 'Chinois simplifié*Langues avec support audio complet', 'Chinois traditionnel', 'Chinês simplificado', 'Chinês simplificado*idiomas com suporte total de áudio', 'Chinês tradicional', 'Chinês tradicional*idiomas com suporte total de áudio', 'Chiński tradycyjny', 'Chiński tradycyjny (text only)', 'Chiński uproszczony', 'Cinese semplificato', 'Cinese tradizionale', 'Cinese tradizionale*lingue con supporto audio completo', 'Coreano', 'Coreano*', 'Coréen', 'Coréen*Langues avec support audio complet', 'Croatian', 'Cseh', 'Czech', 'Czeski', 'Danish', 'Danés', 'Dari', 'Deutsch', 'Deutsch*', 'Dinamarquês', 'Dutch', 'Duński', 'Dán', 'Dänisch', 'Engelsk*', 'Englisch', 'Englisch*', 'Englisch**Sprachen mit voller Audiounterstützung', 'English', 'English\r\nRussian\r\nSpanish - Spain\r\nJapanese\r\nCzech', 'English[b]*[/b]', 'Espagnol - Amérique latine', 'Espagnol - Espagne', 'Espagnol - Espagne*', 'Espanhol (América Latina)', 'Espanhol (América Latina)*idiomas com suporte total de áudio', 'Espanhol (Espanha)', 'Espanhol (Espanha)*', 'Español - España', 'Español - España*', 'Español - Latinoamérica', 'Español de España', 'Español de España*', 'Estonian', 'Filipino', 'Finlandês', 'Finn', 'Finnish', 'Finés', 'Fiński', 'Francese', 'Francese*', 'Francia*', 'Francuski', 'Francuski*', 'Francés', 'Francés*', 'Francês', 'Francês*', 'Fransk', 'Französisch', 'Französisch*', 'Français', 'Français*', 'French', 'Galician', 'Georgian', 'German', 'Giapponese', 'Giapponese*', 'Grecki', 'Greek', 'Grego', 'Griechisch', 'Griego', 'Gujarati', 'Hausa', 'Hebrew', 'Hindi', 'Hiszpański', 'Hiszpański latynoamerykański', 'Hiszpański*', 'Holandés', 'Holandês', 'Holenderski', 'Holland', 'Hungarian', 'Húngaro', 'Icelandic', 'Igbo', 'Indonesian', 'Indonezyjski*języki z pełnym udźwiękowieniem', 'Inglese', 'Inglese*', 'Inglés', 'Inglés*', 'Inglés**idiomas con localización de audio', 'Inglês', 'Inglês*', 'Irish', 'Italian', 'Italian \r\n\r\n[b]', 'Italiano', 'Italiano*', 'Italien', 'Italien*', 'Italienisch', 'Italienisch*', 'Italiensk', 'Japanese', 'Japanese (all with full audio support)', 'Japanisch', 'Japanisch*', 'Japanisch**Sprachen mit voller Audiounterstützung', 'Japanisch*Sprachen mit voller Audiounterstützung', 'Japonais', 'Japonais*', 'Japonés', 'Japonés*', 'Japonés**idiomas con localización de audio', 'Japonês', 'Japonês*', 'Japoński', 'Japán*', "K'iche'", 'Kannada', 'Kazakh', 'Khmer', 'Kinyarwanda', 'Konkani', 'Korean', 'Koreanisch', 'Koreanisch*', 'Koreański', 'Kyrgyz', 'Latvian', 'Lengyel', 'Lithuanian', 'Luxembourgish', 'Macedonian', 'Malay', 'Malayalam', 'Maltese', 'Maori', 'Marathi', 'Mongolian', 'Nepali', 'Niederländisch', 'Niemieck ...

# %%
allowed_tags = ['English', 'Spanish', 'French', 'German', 'Russian', 'Chinese', 'Japanese', 'Italian', 'Finnish', 'Estonian', 'Swedish']

# Filter rows where 'tags' list contains any allowed_tags
main['supported_languages_clean'] = main['supported_languages_clean'].apply(
    lambda lst: [tag for tag in lst if tag in allowed_tags]
)

main.head()
# Out:
#        month  avg_players  gain_percent  peak_players  steam_appid  \
# 0 2025-09-01      7805.25        0.1276         13254           10
# 1 2025-08-01      6922.13       -0.0610         12168           10
# 2 2025-07-01      7371.48       -0.1016         13951           10
# 3 2025-06-01      8204.98       -0.0936         15798           10
# 4 2025-05-01      9052.51       -0.0495         15333           10
#
#              name  type  required_age is_free  \
# 0  Counter-Strike  game           0.0   False
# 1  Counter-Strike  game           0.0   False
# 2  Counter-Strike  game           0.0   False
# 3  Counter-Strike  game           0.0   False
# 4  Counter-Strike  game           0.0   False
#
#                                  supported_languages developers publishers  \
# 0  English<strong>*</strong>, French<strong>*</st...  ['Valve']  ['Valve']
# 1  English<strong>*</strong>, French<strong>*</st...  ['Valve']  ['Valve']
# 2  English<strong>*</strong>, French<strong>*</st...  ['Valve']  ['Valve']
# 3  English<strong>*</strong>, French<strong>*</st...  ['Valve']  ['Valve']
# 4  English<strong>*</strong>, French<strong>*</st...  ['Valve']  ['Valve']
#
#                                        platforms  \
# 0  {'windows': True, 'mac': True, 'linux': True}
# 1  {'windows': True, 'mac': True, 'linux': True}
# 2  {'windows': True, 'mac': True, 'linux': True}
# 3  {'windows': True, 'mac': True, 'linux': True}
# 4  {'windows': True, 'mac': True, 'linux': True}
#
#                                           categories  \
# 0  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 1  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 2  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 3  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 4  [{'id': 1, 'description': 'Multi-player'}, {'i...
#
#                                    genres  \
# 0  [{'id': '1', 'description': 'Action'}]
# 1  [{'id': '1', 'description': 'Action'}]
# 2  [{'id': '1', 'description': 'Action'}]
# 3  [{'id': '1', 'description': 'Action'}]
# 4  [{'id': '1', 'description': 'Action'}]
#
#                                     release_date supported_languages_clean
# 0  {'coming_soon': False, 'date': '1 Nov, 2000'}                 [English]
# 1  {'coming_soon': False, 'date': '1 Nov, 2000'}                 [English]
# 2  {'coming_soon': False, 'date': '1 Nov, 2000'}                 [English]
# 3  {'coming_soon': False, 'date': '1 Nov, 2000'}                 [English]
# 4  {'coming_soon': False, 'date': '1 Nov, 2000'}                 [English]

# %%
popularity['month'].value_counts()
# Out:
# month
# 2019-04-01    6029
# 2019-08-01    6022
# 2019-07-01    6006
# 2019-06-01    5973
# 2019-05-01    5936
#               ...
# 2012-11-01     975
# 2012-10-01     946
# 2012-09-01     911
# 2012-08-01     886
# 2012-07-01     860
# Name: count, Length: 159, dtype: int64

# %%
main['release_date'].value_counts()
#main["release_date"].iloc[0]
# Out:
# release_date
# {'coming_soon': False, 'date': ''}                7677
# {'coming_soon': False, 'date': '30 Aug, 2006'}    2191
# {'coming_soon': False, 'date': '24 Aug, 2009'}    1908
# {'coming_soon': False, 'date': '5 Apr, 2016'}     1683
# {'coming_soon': False, 'date': '15 May, 2014'}    1624
#                                                   ...
# {'coming_soon': False, 'date': '24 Jan, 2020'}       1
# {'coming_soon': False, 'date': '11 Aug, 2020'}       1
# {'coming_soon': False, 'date': '7 Aug, 2019'}        1
# {'coming_soon': False, 'date': '2 Jul, 2019'}        1
# {'coming_soon': False, 'date': '27 Jan, 2018'}       1
# Name: count, Length: 2675, dtype: int64

# %% [markdown]
# ## Cleaning release date

# %%
import ast

main["release_date"] = main["release_date"].apply(
    lambda x: ast.literal_eval(x) if isinstance(x, str) else x
)

# %%
main["release_date"] = pd.to_datetime(
    main["release_date"].apply(lambda x: x.get("date") if isinstance(x, dict) else None),
    format="%d %b, %Y",
    errors="coerce"
)

# %% [markdown]
# ## plotting the change in player counts through game lifetime

# %%
import pandas as pd
import matplotlib.pyplot as plt

# ---- ASSUMPTIONS ----
# df contains:
df = main[['steam_appid', 'month', 'avg_players', 'peak_players', 'gain_percent', 'release_date']]
# df_release contains one row per appid with 'steam_appid' and 'release_date_clean' datetime
# ----------------------

df["month"] = pd.to_datetime(df["month"], errors="coerce")

# Compute time since release in months
df["months_since_release"] = (
    (df["month"].dt.year - df["release_date"].dt.year) * 12 +
    (df["month"].dt.month - df["release_date"].dt.month)
)

# Remove pre-release rows
df = df[df["months_since_release"] >= 0]

# ------------------------------
# NORMALIZE BY TOTAL PLAYERS EACH MONTH
# ------------------------------

# Total players across all games for each month
monthly_totals = df.groupby("month")["avg_players"].sum().rename("total_players")

# Merge totals back
df = df.merge(monthly_totals, on="month", how="left")

# Compute relative share
df["relative_players"] = df["avg_players"] / df["total_players"]

# ------------------------------
# AVERAGE TRAJECTORY RELATIVE TO RELEASE
# ------------------------------
trend = df.groupby("months_since_release")["relative_players"].mean().reset_index()

# ------------------------------
# PLOT
# ------------------------------
plt.figure(figsize=(10, 6))
plt.plot(trend["months_since_release"], trend["relative_players"])
plt.title("Relative Player Share vs. Months Since Release")
plt.xlabel("Months Since Release")
plt.ylabel("Average Player Share (relative to total players that month)")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\kustisam\AppData\Local\Temp\ipykernel_2480\3918913319.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["month"] = pd.to_datetime(df["month"], errors="coerce")
# C:\Users\kustisam\AppData\Local\Temp\ipykernel_2480\3918913319.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["months_since_release"] = (

# %%
monthly_totals = df.groupby("month")["total_players"].first()
monthly_totals.plot()
# Out:
# <Axes: xlabel='month'>

# %% [markdown]
# ## That was garbage, moving on

# %%
df.groupby("month")["total_players"].sum().head(20)
# Out:
# month
# 2012-07-01    3.066141e+08
# 2012-08-01    2.848704e+08
# 2012-09-01    2.650868e+08
# 2012-10-01    2.687992e+08
# 2012-11-01    3.054682e+08
# 2012-12-01    3.504451e+08
# 2013-01-01    3.697990e+08
# 2013-02-01    3.210160e+08
# 2013-03-01    3.399616e+08
# 2013-04-01    3.187681e+08
# 2013-05-01    3.243171e+08
# 2013-06-01    3.472584e+08
# 2013-07-01    4.216657e+08
# 2013-08-01    4.494208e+08
# 2013-09-01    3.833804e+08
# 2013-10-01    4.195806e+08
# 2013-11-01    4.528693e+08
# 2013-12-01    5.808330e+08
# 2014-01-01    5.996225e+08
# 2014-02-01    5.424770e+08
# Name: total_players, dtype: float64

# %%
trend_abs = df.groupby("months_since_release")["avg_players"].mean()
trend_rel = df.groupby("months_since_release")["relative_players"].mean()

print(trend_abs.corr(trend_rel))
# Out:
# 0.9765211471755321
